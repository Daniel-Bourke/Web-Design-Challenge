# %%
import pandas as pd
import requests

# %%
url="Resources/Clean_911 - Copy.csv"

df=pd.read_csv(url)

# %%
df.head(102)
# Out:
#        Dept                Type  YY  MMM  MM  MMM-YY  YYMM   WD  WD#  \
# 0       EMS   BACK PAINS/INJURY  15  Dec  12  Dec-15  1512  Thu    3
# 1       EMS  DIABETIC EMERGENCY  15  Dec  12  Dec-15  1512  Thu    3
# 2      Fire       GAS-ODOR/LEAK  15  Dec  12  Dec-15  1512  Thu    3
# 3       EMS   CARDIAC EMERGENCY  15  Dec  12  Dec-15  1512  Thu    3
# 4       EMS           DIZZINESS  15  Dec  12  Dec-15  1512  Thu    3
# ..      ...                 ...  ..  ...  ..     ...   ...  ...  ...
# 94  Traffic  DISABLED VEHICLE -  15  Dec  12  Dec-15  1512  Thu    3
# 95  Traffic  VEHICLE ACCIDENT -  15  Dec  12  Dec-15  1512  Thu    3
# 96      EMS          CVA/STROKE  15  Dec  12  Dec-15  1512  Thu    3
# 97      EMS         FALL VICTIM  15  Dec  12  Dec-15  1512  Thu    3
# 98      EMS            SEIZURES  15  Dec  12  Dec-15  1512  Thu    3
#
#           Date       Date2  HH      Time            TStamp        lat  \
# ...

# %%
df.to_html("911_data2.html")
